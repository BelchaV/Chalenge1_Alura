# %% [markdown]
# <a href="https://colab.research.google.com/github/BelchaV/Chalenge1_Alura/blob/main/Chalenge3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Traer la Data Normalizada

# %%
import pandas as pd
pd_normal = pd.read_csv('/content/Telecom_normaliz.csv')
pd_normal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               7267 non-null   int64
#  1   customerID               7267 non-null   object
#  2   desercion                7267 non-null   int64
#  3   genero                   7267 non-null   object
#  4   jubilado                 7267 non-null   int64
#  5   enpareja                 7267 non-null   int64
#  6   otros_servicios          7267 non-null   int64
#  7   meses_de_servicio        7267 non-null   int64
#  8   tiene_telefonia          7267 non-null   int64
#  9   phone.MultipleLines      7267 non-null   object
#  10  tiene_internet           7267 non-null   object
#  11  serv_seguridad_enlinea   7267 non-null   object
#  12  serv_respaldo_enlinea    7267 non-null   object
#  13  serv_protec_dispositivo  7267 non-null   object
# ...

# %% [markdown]
# # Preparando las Columnas

# %%
pd_normal = pd_normal.drop(['Unnamed: 0', 'customerID'], axis=1)
pd_normal.head()
# Out:
#    desercion  genero  jubilado  enpareja  otros_servicios  meses_de_servicio  \
# 0          0  Female         0         1                1                  9
# 1          0    Male         0         0                0                  9
# 2          1    Male         0         0                0                  4
# 3          1    Male         1         1                0                 13
# 4          1  Female         1         1                0                  3
#
#    tiene_telefonia phone.MultipleLines tiene_internet serv_seguridad_enlinea  \
# 0                1                  No            DSL                     No
# 1                1                 Yes            DSL                     No
# 2                1                  No    Fiber optic                     No
# 3                1                  No    Fiber optic                     No
# 4                1                  No    Fiber optic                     No
#
# ...

# %%
column_categ=pd_normal.select_dtypes(include='object').columns
print(column_categ)
# Out:
# Index(['genero', 'phone.MultipleLines', 'tiene_internet',
#        'serv_seguridad_enlinea', 'serv_respaldo_enlinea',
#        'serv_protec_dispositivo', 'serv_adic_soporte_tecn', 'tiene_tv_cable',
#        'serv_streaming_pelic', 'tipo_contrato', 'forma_pago'],
#       dtype='object')

# %%
pd_normal.describe()
# Out:
#          desercion     jubilado     enpareja  otros_servicios  \
# count  7267.000000  7267.000000  7267.000000      7267.000000
# mean      0.257190     0.162653     0.484106         0.300124
# std       0.437115     0.369074     0.499782         0.458343
# min       0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000         0.000000
# 50%       0.000000     0.000000     0.000000         0.000000
# 75%       1.000000     0.000000     1.000000         1.000000
# max       1.000000     1.000000     1.000000         1.000000
#
#        meses_de_servicio  tiene_telefonia  fact_electronica  cargo_mensual  \
# count        7267.000000      7267.000000       7267.000000    7267.000000
# mean           32.346498         0.902711          0.593230      64.720098
# std            24.571773         0.296371          0.491265      30.129572
# min             0.000000         0.000000          0.000000      18.250000
# ...

# %%
pd_normal.describe(include="O")
# Out:
#        genero phone.MultipleLines tiene_internet serv_seguridad_enlinea  \
# count    7267                7267           7267                   7267
# unique      2                   3              3                      3
# top      Male                  No    Fiber optic                     No
# freq     3675                3495           3198                   3608
#
#        serv_respaldo_enlinea serv_protec_dispositivo serv_adic_soporte_tecn  \
# count                   7267                    7267                   7267
# unique                     3                       3                      3
# top                       No                      No                     No
# freq                    3182                    3195                   3582
#
#        tiene_tv_cable serv_streaming_pelic   tipo_contrato        forma_pago
# count            7267                 7267            7267              7267
# ...

# %%
#Dado que tenemos Columnas que dependen de Internet (hay un campo que se llama 'tiene_internet') para obtener un 3er valor, vamos a descartar ese valor.
#Ej: tiene_tv_cable (será 1 o 0. Cero signif 'no internet, no tiene_tv_cable)
col_a_normaliz= ['serv_seguridad_enlinea', 'serv_respaldo_enlinea',
             'serv_protec_dispositivo', 'serv_adic_soporte_tecn', 'tiene_tv_cable',
             'serv_streaming_pelic']
#
for i in col_a_normaliz:
   pd_normal[i]=pd_normal[i].replace('No internet service','No')
#Con la columna 'phone...' también hacemos lo mismo, descartamos el 3er. valor
pd_normal['phone.MultipleLines']=pd_normal['phone.MultipleLines'].replace('No phone service','No')
pd_normal.head()
# Out:
#    desercion  genero  jubilado  enpareja  otros_servicios  meses_de_servicio  \
# 0          0  Female         0         1                1                  9
# 1          0    Male         0         0                0                  9
# 2          1    Male         0         0                0                  4
# 3          1    Male         1         1                0                 13
# 4          1  Female         1         1                0                  3
#
#    tiene_telefonia phone.MultipleLines tiene_internet serv_seguridad_enlinea  \
# 0                1                  No            DSL                     No
# 1                1                 Yes            DSL                     No
# 2                1                  No    Fiber optic                     No
# 3                1                  No    Fiber optic                     No
# 4                1                  No    Fiber optic                     No
#
# ...

# %%
#get_dummies
#pd_normal1=pd.get_dummies(pd_normal,drop_first=True)
#pd_normal1.info()

# %%
columnas_a_verificar = ["desercion", "jubilado", "enpareja", "otros_servicios","tiene_telefonia", "fact_electronica" ]
#verifico que las columnas tienen valores booleanos. Y luego transformo el tipo de dato
for col in columnas_a_verificar:
    print(col)
    print(pd_normal[col].unique())
for col in columnas_a_verificar:
    pd_normal[col] = pd_normal[col].astype(bool)
pd_normal.info()
# Out:
# desercion
# [0 1]
# jubilado
# [0 1]
# enpareja
# [1 0]
# otros_servicios
# [1 0]
# tiene_telefonia
# [1 0]
# fact_electronica
# [1 0]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   desercion                7267 non-null   bool
#  1   genero                   7267 non-null   object
#  2   jubilado                 7267 non-null   bool
#  3   enpareja                 7267 non-null   bool
#  4   otros_servicios          7267 non-null   bool
#  5   meses_de_servicio        7267 non-null   int64
#  6   tiene_telefonia          7267 non-null   bool
#  7   phone.MultipleLines      7267 non-null   object
#  8   tiene_internet           7267 non-null   object
#  9   serv_seguridad_enlinea   7267 non-null   object
#  10  serv_respaldo_enlinea    7267 non-null   object
# ...

# %%
#get_dummies
#Convierto las variables categóricas (texto o etiquetas como "Masculino", "Femenino", "Prepago", "Postpago") en números.La mayoría de algoritmos NO trabajan directamente con cadenas de texto.
pd_normal1=pd.get_dummies(pd_normal,drop_first=True)
pd_normal1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 25 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   desercion                           7267 non-null   bool
#  1   jubilado                            7267 non-null   bool
#  2   enpareja                            7267 non-null   bool
#  3   otros_servicios                     7267 non-null   bool
#  4   meses_de_servicio                   7267 non-null   int64
#  5   tiene_telefonia                     7267 non-null   bool
#  6   fact_electronica                    7267 non-null   bool
#  7   cargo_mensual                       7267 non-null   float64
#  8   cargo_total                         7267 non-null   float64
#  9   cuentas_diarias                     7267 non-null   float64
#  10  genero_Male                         7267 non-null   bool
# ...

# %%
#Nuestra variable Objetivo tiene muchos casos (74%) en la clase 'no desertaron'
#Este desbalance se sugiere adecuado para predecir con  ML
pd_normal1['desercion'].value_counts(normalize=True)* 100
# Out:
# desercion
# False    74.280996
# True     25.719004
# Name: proportion, dtype: float64

# %% [markdown]
# ## Balanceo de Clases de la Variable Objetivo (solo propuesta)

# %%
from imblearn.over_sampling import SMOTE
#from sklearn.model_selection import train_test_split

# 1. Definir X (features) e y (target)
##X = pd_normal1.drop('desercion', axis=1)
##y = pd_normal1['desercion']
##smote = SMOTE(random_state=42)
##X_smot, y_smot = smote.fit_resample(X, y)

# %% [markdown]
# # Correlacion de Variables

# %%
corr = pd_normal1.corr()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(20,16))
ax = sns.heatmap(np.round(corr, 2), vmax=1, vmin=-1, center=0,
            square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .5})
plt.show()

# %%
sns.scatterplot(data=pd_normal1, x='meses_de_servicio', y='cargo_total', hue='desercion')
plt.title('Relación entre Meses de Servicio y Cargo Total')
plt.show()

# %%
target_var='desercion'
#corr = pd_normal1.corr()
top_corr = corr[target_var].abs().sort_values(ascending=False)
print("🔝 Top correlaciones con", target_var)
print(top_corr.head(5))
# Out:
# 🔝 Top correlaciones con desercion
# desercion                      1.000000
# meses_de_servicio              0.344079
# tiene_internet_Fiber optic     0.300949
# tipo_contrato_Two year         0.295138
# forma_pago_Electronic check    0.294626
# Name: desercion, dtype: float64

# %%
# Definir la variable objetivo
target_var = 'desercion'

# Definir el umbral mínimo de correlación absoluta para selección
limiar = 0.2

# Filtrar variables que tengan correlación absoluta >= umbral con la variable objetivo
# Esto crea una lista con las variables relevantes
variaveis_relevantes = corr.index[abs(corr[target_var]) >= limiar].tolist()

# Asegurar que la variable objetivo esté en la lista (si no está, añadirla)
if target_var not in variaveis_relevantes:
    variaveis_relevantes.append(target_var)

# Crear una matriz de correlación solo con las variables seleccionadas
corr_filtrada = corr.loc[variaveis_relevantes, variaveis_relevantes]

# Generar una máscara para ocultar el triángulo superior de la matriz (incluida la diagonal)
mascara = np.triu(np.ones_like(corr_filtrada, dtype=bool))

# Graficar el heatmap con la máscara aplicada para mejor visualización
plt.figure(figsize=(12,10))
sns.heatmap(
    corr_filtrada,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.7},
    mask=mascara
)
plt.title(f'Heatmap de variables con correlación >= {limiar} con "{target_var}"')
plt.show()

# %% [markdown]
# # Analisis de Multiconilearidad

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
# Excluimos la variable objetivo (ej: desercion) en el cálculo del VIF.
#X = pd_normal1.drop(columns=['desercion'])
#Tambien elimino la columna 'cuentas_diarias' que son colineales entre si con 'cargo_mensual'. La evidencia es un VIF=inf que da si no quito 'cuentas_diarias'
X = pd_normal1.drop(columns=['desercion','cuentas_diarias'])
X_const = add_constant(X)
# Convert boolean columns to integers (0 or 1)
X_const = X_const.astype(float)
# Calcular el VIF
vif_data = pd.DataFrame()
vif_data["feature"] = X_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]

# Mostrar resultado
display(vif_data.sort_values(by='VIF', ascending=False))
# Out:
#                                feature         VIF
# 7                        cargo_mensual  871.464258
# 0                                const  630.714022
# 11          tiene_internet_Fiber optic  149.020441
# 12                   tiene_internet_No  105.056440
# 5                      tiene_telefonia   35.174704
# 18            serv_streaming_pelic_Yes   24.203807
# 17                  tiene_tv_cable_Yes   24.123237
# 8                          cargo_total   10.815154
# 4                    meses_de_servicio    7.524785
# 10             phone.MultipleLines_Yes    7.302265
# 15         serv_protec_dispositivo_Yes    6.950955
# 14           serv_respaldo_enlinea_Yes    6.812465
# 16          serv_adic_soporte_tecn_Yes    6.470562
# 13          serv_seguridad_enlinea_Yes    6.347212
# 20              tipo_contrato_Two year    2.630997
# 22         forma_pago_Electronic check    1.979823
# 23             forma_pago_Mailed check    1.862275
# ...

# %% [markdown]
# * Análisis de Vif:
#
# Rango de VIF	Interpretación
#
# VIF ≈ 1	      Sin multicolinealidad (óptimo)
# 1 < VIF ≤ 5	  Baja (aceptable)
# 5 < VIF ≤ 10	Moderada (vigilar)
# VIF > 10	Alta (atención o posible exclusión)
#
# ---
#
# * Conclusión práctica
#
# **La multicolinealidad crítica fue resuelta** (sin `inf`, sin redundancia perfecta)
# **Solo `Charges.Monthly` y `Charges.Total` siguen colineales entre sí** — esto ya era esperado
#
# ---

# %% [markdown]
# # Modelos Predictivos
